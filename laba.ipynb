# %% [markdown]
# ЗАДАНИЕ 1,2

# %%
from sqlalchemy import ForeignKey, create_engine, Column, Integer, String, DateTime,Date, select
from sqlalchemy.orm import DeclarativeBase,Mapped,mapped_column,relationship
from sqlalchemy.orm import sessionmaker

database_url = 'mssql+pyodbc://sa:Senya_13.05.07@15-2-441-17\HICO69/hico69_laba_sql?driver=ODBC+driver+17+for+SQL+Server'
engine = create_engine(database_url,echo=True)

class Base(DeclarativeBase):
    pass

class GROUPS(Base):
    __tablename__ = 'GROUPS'
    GROUP_ID : Mapped[int] = mapped_column(primary_key=True)
    NAME_GROUP: Mapped[str] = mapped_column(String(15),nullable=False)
    COURSE:Mapped[int]

class STUDENTS(Base):
    __tablename__ = 'STUDENTS'
    STUDENT_ID: Mapped[int] = mapped_column(primary_key=True)
    NAME_STUDENT: Mapped[str] = mapped_column(String(35),nullable=False)
    SURNAME_STUDENT: Mapped[str] = mapped_column(String(35),nullable=False)
    STUDENTS_SECONDNAME: Mapped[str] = mapped_column(String(35),nullable=False)
    BIRTHDAY: Mapped[DateTime] = mapped_column(Date)
    GROUP_ID: Mapped[int] = mapped_column(ForeignKey("GROUPS.GROUP_ID"))

class SUBJECTS(Base):
    __tablename__ = 'SUBJECTS'
    SUBJECT_ID: Mapped[int] = mapped_column(primary_key=True)
    SUBJECT_NAME: Mapped[str] = mapped_column(String(50),nullable=False)
    SUBJECT_HOURS: Mapped[int]

class PLANN(Base):
    __tablename__ = 'PLANN'
    SUBJECT_ID: Mapped[int] = mapped_column(ForeignKey("SUBJECTS.SUBJECT_ID"),primary_key=True)
    GROUP_ID: Mapped[int] = mapped_column(ForeignKey("GROUPS.GROUP_ID"),primary_key=True)

Base.metadata.create_all(engine)
# Out:
# 2026-04-10 15:35:16,202 INFO sqlalchemy.engine.Engine SELECT CAST(SERVERPROPERTY('ProductVersion') AS VARCHAR)
# 2026-04-10 15:35:16,203 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-04-10 15:35:16,204 INFO sqlalchemy.engine.Engine SELECT schema_name()
# 2026-04-10 15:35:16,204 INFO sqlalchemy.engine.Engine [generated in 0.00048s] ()
# <>:5: SyntaxWarning: invalid escape sequence '\H'
# <>:5: SyntaxWarning: invalid escape sequence '\H'
# C:\Users\hico69\AppData\Local\Temp\ipykernel_13952\4254671806.py:5: SyntaxWarning: invalid escape sequence '\H'
#   database_url = 'mssql+pyodbc://sa:Senya_13.05.07@15-2-441-17\HICO69/hico69_laba_sql?driver=ODBC+driver+17+for+SQL+Server'
# 2026-04-10 15:35:16,213 INFO sqlalchemy.engine.Engine SELECT CAST('test max support' AS NVARCHAR(max))
# 2026-04-10 15:35:16,214 INFO sqlalchemy.engine.Engine [generated in 0.00057s] ()
# ...

# %% [markdown]
# ЗАДАНИЕ 3

# %%
Session = sessionmaker(bind=engine)
session = Session()

def insert_groups():
    group1 = GROUPS(NAME_GROUP = 'ПО135', COURSE = '1')
    group2 = GROUPS(NAME_GROUP = 'ПО235', COURSE = '2')
    group3 = GROUPS(NAME_GROUP = 'ПО335', COURSE = '3')
    session.add(group1)
    session.add(group2)
    session.add(group3)
    session.commit()

def insert_subjects():
    subject1 = SUBJECTS(SUBJECT_NAME ='Физика',SUBJECT_HOURS ='200')
    subject2 = SUBJECTS(SUBJECT_NAME ='Математика',SUBJECT_HOURS ='120')
    subject3 = SUBJECTS(SUBJECT_NAME ='Основы алгоритмизации',SUBJECT_HOURS ='70')
    subject4 = SUBJECTS(SUBJECT_NAME ='Проектирование БД',SUBJECT_HOURS ='130')
    subject5 = SUBJECTS(SUBJECT_NAME ='Средства визуального программирования',SUBJECT_HOURS ='90')
    subject6 = SUBJECTS(SUBJECT_NAME ='Объектно-ориентированное программирование',SUBJECT_HOURS ='70')
    session.add(subject1)
    session.add(subject2)
    session.add(subject3)
    session.add(subject4)
    session.add(subject5)
    session.add(subject6)
    session.commit()

def insert_students():
    student1 = STUDENTS(NAME_STUDENT ='Федоренко',SURNAME_STUDENT ='П.',STUDENTS_SECONDNAME ='Р.',BIRTHDAY = '1997-12-25',GROUP_ID=4)
    student2 = STUDENTS(NAME_STUDENT ='Зингел',SURNAME_STUDENT ='О.',STUDENTS_SECONDNAME ='NULL',BIRTHDAY = '1985-12-25',GROUP_ID=4)
    student3 = STUDENTS(NAME_STUDENT ='Савицкая',SURNAME_STUDENT ='Н.',STUDENTS_SECONDNAME ='NULL',BIRTHDAY = '1987-09-22',GROUP_ID=5)
    student4 = STUDENTS(NAME_STUDENT ='Ковальчук',SURNAME_STUDENT ='М.',STUDENTS_SECONDNAME ='E.',BIRTHDAY = '1992-06-17',GROUP_ID=5)
    student5 = STUDENTS(NAME_STUDENT ='Ковриго',SURNAME_STUDENT ='Т.',STUDENTS_SECONDNAME ='Р.',BIRTHDAY = '1992-05-13',GROUP_ID=6)
    student6 = STUDENTS(NAME_STUDENT ='Шарапо',SURNAME_STUDENT ='Н.',STUDENTS_SECONDNAME ='NULL',BIRTHDAY = '1992-08-14',GROUP_ID=6)
    session.add(student1)
    session.add(student2)
    session.add(student3)
    session.add(student4)
    session.add(student5)
    session.add(student6)
    session.commit()

def insert_plann():
    plan1 = PLANN(GROUP_ID =4,SUBJECT_ID =1)
    plan2 = PLANN(GROUP_ID =4,SUBJECT_ID =2)
    plan3 = PLANN(GROUP_ID =5,SUBJECT_ID =3)
    plan4 = PLANN(GROUP_ID =5,SUBJECT_ID =4)
    plan5 = PLANN(GROUP_ID =6,SUBJECT_ID =5)
    plan6 = PLANN(GROUP_ID =6,SUBJECT_ID =6)
    session.add(plan1)
    session.add(plan2)
    session.add(plan3)
    session.add(plan4)
    session.add(plan5)
    session.add(plan6)
    session.commit()

# %%
insert_groups()
# Out:
# 2026-04-10 15:36:15,699 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-10 15:36:15,700 INFO sqlalchemy.engine.Engine INSERT INTO [GROUPS] ([NAME_GROUP], [COURSE]) OUTPUT inserted.[GROUP_ID], inserted.[GROUP_ID] AS [GROUP_ID__1] SELECT p0, p1 FROM (VALUES (?, ?, 0), (?, ?, 1), (?, ?, 2)) AS imp_sen(p0, p1, sen_counter) ORDER BY sen_counter
# 2026-04-10 15:36:15,701 INFO sqlalchemy.engine.Engine [cached since 16.5s ago (insertmanyvalues) 1/1 (ordered)] ('ПО135', '1', 'ПО235', '2', 'ПО335', '3')
# 2026-04-10 15:36:15,702 INFO sqlalchemy.engine.Engine COMMIT

# %%
insert_subjects()
# Out:
# 2026-04-10 15:36:17,414 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-10 15:36:17,415 INFO sqlalchemy.engine.Engine INSERT INTO [SUBJECTS] ([SUBJECT_NAME], [SUBJECT_HOURS]) OUTPUT inserted.[SUBJECT_ID], inserted.[SUBJECT_ID] AS [SUBJECT_ID__1] SELECT p0, p1 FROM (VALUES (?, ?, 0), (?, ?, 1), (?, ?, 2), (?, ?, 3), (?, ?, 4), (?, ?, 5)) AS imp_sen(p0, p1, sen_counter) ORDER BY sen_counter
# 2026-04-10 15:36:17,416 INFO sqlalchemy.engine.Engine [cached since 18.21s ago (insertmanyvalues) 1/1 (ordered)] ('Физика', '200', 'Математика', '120', 'Основы алгоритмизации', '70', 'Проектирование БД', '130', 'Средства визуального программирования', '90', 'Объектно-ориентированное программирование', '70')
# 2026-04-10 15:36:17,418 INFO sqlalchemy.engine.Engine COMMIT

# %%
insert_students()
# Out:
# 2026-04-10 15:36:19,886 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-10 15:36:19,887 INFO sqlalchemy.engine.Engine INSERT INTO [STUDENTS] ([NAME_STUDENT], [SURNAME_STUDENT], [STUDENTS_SECONDNAME], [BIRTHDAY], [GROUP_ID]) OUTPUT inserted.[STUDENT_ID], inserted.[STUDENT_ID] AS [STUDENT_ID__1] SELECT p0, p1, p2, p3, p4 FROM (VALUES (?, ?, ?, ?, ?, 0), (?, ?, ?, ?, ?, 1), (?, ?, ?, ?, ?, 2), (?, ?, ?, ?, ?, 3), (?, ?, ?, ?, ?, 4), (?, ?, ?, ?, ?, 5)) AS imp_sen(p0, p1, p2, p3, p4, sen_counter) ORDER BY sen_counter
# 2026-04-10 15:36:19,887 INFO sqlalchemy.engine.Engine [cached since 20.67s ago (insertmanyvalues) 1/1 (ordered)] ('Федоренко', 'П.', 'Р.', '1997-12-25', 4, 'Зингел', 'О.', 'NULL', '1985-12-25', 4, 'Савицкая', 'Н.', 'NULL', '1987-09-22', 5, 'Ковальчук', 'М.', 'E.', '1992-06-17', 5, 'Ковриго', 'Т.', 'Р.', '1992-05-13', 6, 'Шарапо', 'Н.', 'NULL', '1992-08-14', 6)
# 2026-04-10 15:36:19,889 INFO sqlalchemy.engine.Engine COMMIT

# %%
insert_plann()
# Out:
# 2026-04-10 15:36:21,831 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-10 15:36:21,833 INFO sqlalchemy.engine.Engine INSERT INTO [PLANN] ([SUBJECT_ID], [GROUP_ID]) VALUES (?, ?), (?, ?), (?, ?), (?, ?), (?, ?), (?, ?)
# 2026-04-10 15:36:21,834 INFO sqlalchemy.engine.Engine [generated in 0.00015s (insertmanyvalues) 1/1 (unordered)] (1, 4, 2, 4, 3, 5, 4, 5, 5, 6, 6, 6)
# 2026-04-10 15:36:21,841 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ЗАДАНИЕ 4

# %%
new_g = GROUPS(NAME_GROUP="ПО134", COURSE=1)
session.add(new_g)
session.commit()

session.query(PLANN).filter(PLANN.GROUP_ID == 1).update({PLANN.GROUP_ID: new_g.GROUP_ID})
session.query(STUDENTS).filter(STUDENTS.GROUP_ID == 1).update({STUDENTS.GROUP_ID: new_g.GROUP_ID})
session.commit()
# Out:
# 2026-04-10 15:36:44,367 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-10 15:36:44,369 INFO sqlalchemy.engine.Engine INSERT INTO [GROUPS] ([NAME_GROUP], [COURSE]) OUTPUT inserted.[GROUP_ID] VALUES (?, ?)
# 2026-04-10 15:36:44,369 INFO sqlalchemy.engine.Engine [generated in 0.00064s] ('ПО134', 1)
# 2026-04-10 15:36:44,372 INFO sqlalchemy.engine.Engine COMMIT
# 2026-04-10 15:36:44,375 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-10 15:36:44,378 INFO sqlalchemy.engine.Engine SELECT [GROUPS].[GROUP_ID] AS [GROUPS_GROUP_ID], [GROUPS].[NAME_GROUP] AS [GROUPS_NAME_GROUP], [GROUPS].[COURSE] AS [GROUPS_COURSE]
# FROM [GROUPS]
# WHERE [GROUPS].[GROUP_ID] = ?
# 2026-04-10 15:36:44,379 INFO sqlalchemy.engine.Engine [generated in 0.00178s] (7,)
# 2026-04-10 15:36:44,417 INFO sqlalchemy.engine.Engine UPDATE [PLANN] SET [GROUP_ID]=? WHERE [PLANN].[GROUP_ID] = ?
# 2026-04-10 15:36:44,418 INFO sqlalchemy.engine.Engine [generated in 0.00112s] (7, 1)
# ...

# %% [markdown]
# ЗАДАНИЕ 5

# %%
old_g = session.query(GROUPS).filter(GROUPS.NAME_GROUP == "ПО135").first()
if old_g:
    session.delete(old_g)
    session.commit()
# Out:
# 2026-04-10 15:41:59,460 INFO sqlalchemy.engine.Engine SELECT TOP 1 [GROUPS].[GROUP_ID] AS [GROUPS_GROUP_ID], [GROUPS].[NAME_GROUP] AS [GROUPS_NAME_GROUP], [GROUPS].[COURSE] AS [GROUPS_COURSE]
# FROM [GROUPS]
# WHERE [GROUPS].[NAME_GROUP] = ?
# 2026-04-10 15:41:59,461 INFO sqlalchemy.engine.Engine [generated in 0.00127s] ('ПО135',)
# 2026-04-10 15:41:59,465 INFO sqlalchemy.engine.Engine DELETE FROM [GROUPS] WHERE [GROUPS].[GROUP_ID] = ?
# 2026-04-10 15:41:59,466 INFO sqlalchemy.engine.Engine [generated in 0.00071s] (1,)
# 2026-04-10 15:41:59,470 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ЗАДАНИЕ 6

# %%
session.query(SUBJECTS).filter(SUBJECTS.SUBJECT_NAME == "Средства визуального программирования").update({SUBJECTS.SUBJECT_HOURS: 120})
session.query(SUBJECTS).filter(SUBJECTS.SUBJECT_NAME == "Объектно-ориентированное программирование").update({SUBJECTS.SUBJECT_HOURS: 100})
session.commit()
# Out:
# 2026-04-10 15:43:35,399 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-10 15:43:35,400 INFO sqlalchemy.engine.Engine UPDATE [SUBJECTS] SET [SUBJECT_HOURS]=? WHERE [SUBJECTS].[SUBJECT_NAME] = ?
# 2026-04-10 15:43:35,401 INFO sqlalchemy.engine.Engine [generated in 0.00124s] (120, 'Средства визуального программирования')
# 2026-04-10 15:43:35,407 INFO sqlalchemy.engine.Engine UPDATE [SUBJECTS] SET [SUBJECT_HOURS]=? WHERE [SUBJECTS].[SUBJECT_NAME] = ?
# 2026-04-10 15:43:35,408 INFO sqlalchemy.engine.Engine [cached since 0.008083s ago] (100, 'Объектно-ориентированное программирование')
# 2026-04-10 15:43:35,411 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ЗАДАНИЕ 7

# %%
session.execute(text("ALTER TABLE SUBJECTS ADD EXAM_TYPE NVARCHAR(10)"))
session.commit()
session.execute(text("UPDATE SUBJECTS SET EXAM_TYPE = 'Экзамен'"))
session.execute(text("UPDATE SUBJECTS SET EXAM_TYPE = 'Зачёт' WHERE name_subject = 'Основы алгоритмизации'"))
session.commit()

# %% [markdown]
# ЗАДАНИЕ 8

# %%
session.execute(text("ALTER TABLE STUDENTS DROP COLUMN second_name"))
session.commit()

# %%
session.close()
