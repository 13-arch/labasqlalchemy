# %% [markdown]
# ЗАДАНИЕ 1,2

# %%
from sqlalchemy import ForeignKey, create_engine, Column, Integer, String, DateTime,Date, select
from sqlalchemy.orm import DeclarativeBase,Mapped,mapped_column,relationship
from sqlalchemy.orm import sessionmaker

database_url = 'mssql+pyodbc://uzver:12345678@15-2-441-1-PREP/hico69_laba_sql?driver=ODBC+driver+17+for+SQL+Server'
engine = create_engine(database_url,echo=True)

class Base(DeclarativeBase):
    pass

class GROUPS(Base):
    __tablename__ = 'GROUPS'
    GROUP_ID : Mapped[int] = mapped_column(primary_key=True)
    NAME_GROUP: Mapped[str] = mapped_column(String(15),nullable=False)
    COURSE:Mapped[int]

class STUDENTS(Base):
    __tablename__ = 'STUDENTS'
    STUDENT_ID: Mapped[int] = mapped_column(primary_key=True)
    NAME_STUDENT: Mapped[str] = mapped_column(String(35),nullable=False)
    SURNAME_STUDENT: Mapped[str] = mapped_column(String(35),nullable=False)
    STUDENTS_SECONDNAME: Mapped[str] = mapped_column(String(35),nullable=False)
    BIRTHDAY: Mapped[DateTime] = mapped_column(Date)
    GROUP_ID: Mapped[int] = mapped_column(ForeignKey("GROUPS.GROUP_ID"))

class SUBJECTS(Base):
    __tablename__ = 'SUBJECTS'
    SUBJECT_ID: Mapped[int] = mapped_column(primary_key=True)
    SUBJECT_NAME: Mapped[str] = mapped_column(String(50),nullable=False)
    SUBJECT_HOURS: Mapped[int]

class PLANN(Base):
    __tablename__ = 'PLANN'
    SUBJECT_ID: Mapped[int] = mapped_column(ForeignKey("SUBJECTS.SUBJECT_ID"),primary_key=True)
    GROUP_ID: Mapped[int] = mapped_column(ForeignKey("GROUPS.GROUP_ID"),primary_key=True)

Base.metadata.create_all(engine)
# Out:
# 2026-04-10 13:21:34,044 INFO sqlalchemy.engine.Engine SELECT CAST(SERVERPROPERTY('ProductVersion') AS VARCHAR)
# 2026-04-10 13:21:34,045 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-04-10 13:21:34,047 INFO sqlalchemy.engine.Engine SELECT schema_name()
# 2026-04-10 13:21:34,048 INFO sqlalchemy.engine.Engine [generated in 0.00092s] ()
# 2026-04-10 13:21:34,062 INFO sqlalchemy.engine.Engine SELECT CAST('test max support' AS NVARCHAR(max))
# 2026-04-10 13:21:34,063 INFO sqlalchemy.engine.Engine [generated in 0.00109s] ()
# 2026-04-10 13:21:34,064 INFO sqlalchemy.engine.Engine SELECT 1 FROM fn_listextendedproperty(default, default, default, default, default, default, default)
# 2026-04-10 13:21:34,065 INFO sqlalchemy.engine.Engine [generated in 0.00075s] ()
# 2026-04-10 13:21:34,099 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-10 13:21:34,101 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE ([INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max)) OR [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max))) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME] = CAST(? AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max))
# 2026-04-10 13:21:34,102 INFO sqlalchemy.engine.Engine [generated in 0.00068s] ('BASE TABLE', 'VIEW', 'GROUPS', 'dbo')
# 2026-04-10 13:21:34,117 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE ([INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max)) OR [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max))) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME] = CAST(? AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max))
# 2026-04-10 13:21:34,117 INFO sqlalchemy.engine.Engine [cached since 0.01641s ago] ('BASE TABLE', 'VIEW', 'STUDENTS', 'dbo')
# 2026-04-10 13:21:34,119 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE ([INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max)) OR [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max))) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME] = CAST(? AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max))
# 2026-04-10 13:21:34,120 INFO sqlalchemy.engine.Engine [cached since 0.01909s ago] ('BASE TABLE', 'VIEW', 'SUBJECTS', 'dbo')
# 2026-04-10 13:21:34,122 INFO sqlalchemy.engine.Engine SELECT [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME]
# FROM [INFORMATION_SCHEMA].[TABLES]
# WHERE ([INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max)) OR [INFORMATION_SCHEMA].[TABLES].[TABLE_TYPE] = CAST(? AS NVARCHAR(max))) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_NAME] = CAST(? AS NVARCHAR(max)) AND [INFORMATION_SCHEMA].[TABLES].[TABLE_SCHEMA] = CAST(? AS NVARCHAR(max))
# 2026-04-10 13:21:34,123 INFO sqlalchemy.engine.Engine [cached since 0.02201s ago] ('BASE TABLE', 'VIEW', 'PLANN', 'dbo')
# 2026-04-10 13:21:34,125 INFO sqlalchemy.engine.Engine
# CREATE TABLE [GROUPS] (
# 	[GROUP_ID] INTEGER NOT NULL IDENTITY,
# 	[NAME_GROUP] VARCHAR(15) NOT NULL,
# 	[COURSE] INTEGER NOT NULL,
# 	PRIMARY KEY ([GROUP_ID])
# )
#
#
# 2026-04-10 13:21:34,126 INFO sqlalchemy.engine.Engine [no key 0.00063s] ()
# 2026-04-10 13:21:34,128 INFO sqlalchemy.engine.Engine
# CREATE TABLE [SUBJECTS] (
# 	[SUBJECT_ID] INTEGER NOT NULL IDENTITY,
# 	[SUBJECT_NAME] VARCHAR(50) NOT NULL,
# 	[SUBJECT_HOURS] INTEGER NOT NULL,
# 	PRIMARY KEY ([SUBJECT_ID])
# )
#
#
# 2026-04-10 13:21:34,128 INFO sqlalchemy.engine.Engine [no key 0.00045s] ()
# 2026-04-10 13:21:34,131 INFO sqlalchemy.engine.Engine
# CREATE TABLE [STUDENTS] (
# 	[STUDENT_ID] INTEGER NOT NULL IDENTITY,
# 	[NAME_STUDENT] VARCHAR(35) NOT NULL,
# 	[SURNAME_STUDENT] VARCHAR(35) NOT NULL,
# 	[STUDENTS_SECONDNAME] VARCHAR(35) NOT NULL,
# 	[BIRTHDAY] DATE NOT NULL,
# 	[GROUP_ID] INTEGER NOT NULL,
# 	PRIMARY KEY ([STUDENT_ID]),
# 	FOREIGN KEY([GROUP_ID]) REFERENCES [GROUPS] ([GROUP_ID])
# )
#
#
# 2026-04-10 13:21:34,132 INFO sqlalchemy.engine.Engine [no key 0.00134s] ()
# 2026-04-10 13:21:34,135 INFO sqlalchemy.engine.Engine
# CREATE TABLE [PLANN] (
# 	[SUBJECT_ID] INTEGER NOT NULL,
# 	[GROUP_ID] INTEGER NOT NULL,
# 	PRIMARY KEY ([SUBJECT_ID], [GROUP_ID]),
# 	FOREIGN KEY([SUBJECT_ID]) REFERENCES [SUBJECTS] ([SUBJECT_ID]),
# 	FOREIGN KEY([GROUP_ID]) REFERENCES [GROUPS] ([GROUP_ID])
# )
#
#
# 2026-04-10 13:21:34,135 INFO sqlalchemy.engine.Engine [no key 0.00068s] ()
# 2026-04-10 13:21:34,138 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ЗАДАНИЕ 3

# %%
Session = sessionmaker(bind=engine)
session = Session()

def insert_groups():
    group1 = GROUPS(NAME_GROUP = 'ПО135', COURSE = '1')
    group2 = GROUPS(NAME_GROUP = 'ПО235', COURSE = '2')
    group3 = GROUPS(NAME_GROUP = 'ПО335', COURSE = '3')
    session.add(group1)
    session.add(group2)
    session.add(group3)
    session.commit()

def insert_subjects():
    subject1 = SUBJECTS(SUBJECT_NAME ='Физика',SUBJECT_HOURS ='200')
    subject2 = SUBJECTS(SUBJECT_NAME ='Математика',SUBJECT_HOURS ='120')
    subject3 = SUBJECTS(SUBJECT_NAME ='Основы алгоритмизации',SUBJECT_HOURS ='70')
    subject4 = SUBJECTS(SUBJECT_NAME ='Проектирование БД',SUBJECT_HOURS ='130')
    subject5 = SUBJECTS(SUBJECT_NAME ='Средства визуального программирования',SUBJECT_HOURS ='90')
    subject6 = SUBJECTS(SUBJECT_NAME ='Объектно-ориентированное программирование',SUBJECT_HOURS ='70')
    session.add(subject1)
    session.add(subject2)
    session.add(subject3)
    session.add(subject4)
    session.add(subject5)
    session.add(subject6)
    session.commit()

def insert_students():
    student1 = STUDENTS(NAME_STUDENT ='Федоренко',SURNAME_STUDENT ='П.',STUDENTS_SECONDNAME ='Р.',BIRTHDAY = '1997-12-25',GROUP_ID=4)
    student2 = STUDENTS(NAME_STUDENT ='Зингел',SURNAME_STUDENT ='О.',STUDENTS_SECONDNAME ='NULL',BIRTHDAY = '1985-12-25',GROUP_ID=4)
    student3 = STUDENTS(NAME_STUDENT ='Савицкая',SURNAME_STUDENT ='Н.',STUDENTS_SECONDNAME ='NULL',BIRTHDAY = '1987-09-22',GROUP_ID=5)
    student4 = STUDENTS(NAME_STUDENT ='Ковальчук',SURNAME_STUDENT ='М.',STUDENTS_SECONDNAME ='E.',BIRTHDAY = '1992-06-17',GROUP_ID=5)
    student5 = STUDENTS(NAME_STUDENT ='Ковриго',SURNAME_STUDENT ='Т.',STUDENTS_SECONDNAME ='Р.',BIRTHDAY = '1992-05-13',GROUP_ID=6)
    student6 = STUDENTS(NAME_STUDENT ='Шарапо',SURNAME_STUDENT ='Н.',STUDENTS_SECONDNAME ='NULL',BIRTHDAY = '1992-08-14',GROUP_ID=6)
    session.add(student1)
    session.add(student2)
    session.add(student3)
    session.add(student4)
    session.add(student5)
    session.add(student6)
    session.commit()

def insert_plann():
    plan1 = PLANN(GROUP_ID =4,SUBJECT_ID =1)
    plan2 = PLANN(GROUP_ID =4,SUBJECT_ID =2)
    plan3 = PLANN(GROUP_ID =5,SUBJECT_ID =3)
    plan4 = PLANN(GROUP_ID =5,SUBJECT_ID =4)
    plan5 = PLANN(GROUP_ID =6,SUBJECT_ID =5)
    plan6 = PLANN(GROUP_ID =6,SUBJECT_ID =6)
    session.add(plan1)
    session.add(plan2)
    session.add(plan3)
    session.add(plan4)
    session.add(plan5)
    session.add(plan6)
    session.commit()

# %%
insert_groups()
# Out:
# 2026-04-10 13:21:44,458 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-10 13:21:44,460 INFO sqlalchemy.engine.Engine INSERT INTO [GROUPS] ([NAME_GROUP], [COURSE]) OUTPUT inserted.[GROUP_ID], inserted.[GROUP_ID] AS [GROUP_ID__1] SELECT p0, p1 FROM (VALUES (?, ?, 0), (?, ?, 1), (?, ?, 2)) AS imp_sen(p0, p1, sen_counter) ORDER BY sen_counter
# 2026-04-10 13:21:44,461 INFO sqlalchemy.engine.Engine [generated in 0.00013s (insertmanyvalues) 1/1 (ordered)] ('ПО135', '1', 'ПО235', '2', 'ПО335', '3')
# 2026-04-10 13:21:44,469 INFO sqlalchemy.engine.Engine COMMIT

# %%
insert_subjects()
# Out:
# 2026-04-10 13:21:46,252 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-10 13:21:46,254 INFO sqlalchemy.engine.Engine INSERT INTO [SUBJECTS] ([SUBJECT_NAME], [SUBJECT_HOURS]) OUTPUT inserted.[SUBJECT_ID], inserted.[SUBJECT_ID] AS [SUBJECT_ID__1] SELECT p0, p1 FROM (VALUES (?, ?, 0), (?, ?, 1), (?, ?, 2), (?, ?, 3), (?, ?, 4), (?, ?, 5)) AS imp_sen(p0, p1, sen_counter) ORDER BY sen_counter
# 2026-04-10 13:21:46,255 INFO sqlalchemy.engine.Engine [generated in 0.00013s (insertmanyvalues) 1/1 (ordered)] ('Физика', '200', 'Математика', '120', 'Основы алгоритмизации', '70', 'Проектирование БД', '130', 'Средства визуального программирования', '90', 'Объектно-ориентированное программирование', '70')
# 2026-04-10 13:21:46,263 INFO sqlalchemy.engine.Engine COMMIT

# %%
insert_students()
# Out:
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 insert_students()
#
# Cell In[35], line 41, in insert_students()
#      39 session.add(student5)
#      40 session.add(student6)
# ---> 41 session.commit()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\session.py:2030, in Session.commit(self)
#    2027 if trans is None:
#    2028     trans = self._autobegin_t()
# -> 2030 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\state_changes.py:101, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#      95 current_state = self._state
#      97 if (
#      98     has_prerequisite_states
#      99     and current_state not in prerequisite_state_collection
#     100 ):
# --> 101     self._raise_for_prerequisite_state(fn.__name__, current_state)
#     103 next_state = self._next_state
#     104 existing_fn = self._current_fn
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\session.py:971, in SessionTransaction._raise_for_prerequisite_state(self, operation_name, state)
#     969 if state is SessionTransactionState.DEACTIVE:
#     970     if self._rollback_exception:
# --> 971         raise sa_exc.PendingRollbackError(
#     972             "This Session's transaction has been rolled back "
#     973             "due to a previous exception during flush."
#     974             " To begin a new transaction with this Session, "
#     975             "first issue Session.rollback()."
#     976             f" Original exception was: {self._rollback_exception}",
#     977             code="7s2a",
#     978         )
#     979     else:
#     980         raise sa_exc.InvalidRequestError(
#     981             "This session is in 'inactive' state, due to the "
#     982             "SQL transaction being rolled back; no further SQL "
#     983             "can be emitted within this transaction."
#     984         )
#
# PendingRollbackError: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pyodbc.IntegrityError) ('23000', '[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Конфликт инструкции INSERT с ограничением FOREIGN KEY "FK__PLANN__GROUP_ID__71D1E811". Конфликт произошел в базе данных "hico69_laba_sql", таблица "dbo.GROUPS", column \'GROUP_ID\'. (547) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Выполнение данной инструкции было прервано. (3621)')
# [SQL: INSERT INTO [PLANN] ([SUBJECT_ID], [GROUP_ID]) VALUES (?, ?), (?, ?), (?, ?), (?, ?), (?, ?), (?, ?)]
# [parameters: (1, 4, 2, 4, 3, 5, 4, 5, 5, 6, 6, 6)]
# (Background on this error at: https://sqlalche.me/e/20/gkpj) (Background on this error at: https://sqlalche.me/e/20/7s2a)

# %%
insert_plann()
# Out:
# 2026-04-10 13:21:50,980 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-10 13:21:50,982 INFO sqlalchemy.engine.Engine INSERT INTO [PLANN] ([SUBJECT_ID], [GROUP_ID]) VALUES (?, ?), (?, ?), (?, ?), (?, ?), (?, ?), (?, ?)
# 2026-04-10 13:21:50,983 INFO sqlalchemy.engine.Engine [generated in 0.00019s (insertmanyvalues) 1/1 (unordered)] (1, 4, 2, 4, 3, 5, 4, 5, 5, 6, 6, 6)
# 2026-04-10 13:21:50,995 INFO sqlalchemy.engine.Engine ROLLBACK
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:2125, in Connection._exec_insertmany_context(self, dialect, context)
#    2124     else:
# -> 2125         dialect.do_execute(
#    2126             cursor,
#    2127             sub_stmt,
#    2128             sub_params,
#    2129             context,
#    2130         )
#    2132 except BaseException as e:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# IntegrityError: ('23000', '[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Конфликт инструкции INSERT с ограничением FOREIGN KEY "FK__PLANN__GROUP_ID__71D1E811". Конфликт произошел в базе данных "hico69_laba_sql", таблица "dbo.GROUPS", column \'GROUP_ID\'. (547) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Выполнение данной инструкции было прервано. (3621)')
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 insert_plann()
#
# Cell In[35], line 56, in insert_plann()
#      54 session.add(plan5)
#      55 session.add(plan6)
# ---> 56 session.commit()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\session.py:2030, in Session.commit(self)
#    2027 if trans is None:
#    2028     trans = self._autobegin_t()
# -> 2030 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\session.py:1311, in SessionTransaction.commit(self, _to_root)
#    1309 if self._state is not SessionTransactionState.PREPARED:
#    1310     with self._expect_state(SessionTransactionState.PREPARED):
# -> 1311         self._prepare_impl()
#    1313 if self._parent is None or self.nested:
#    1314     for conn, trans, should_commit, autoclose in set(
#    1315         self._connections.values()
#    1316     ):
#
# File <string>:2, in _prepare_impl(self)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\session.py:1286, in SessionTransaction._prepare_impl(self)
#    1284     if self.session._is_clean():
#    1285         break
# -> 1286     self.session.flush()
#    1287 else:
#    1288     raise exc.FlushError(
#    1289         "Over 100 subsequent flushes have occurred within "
#    1290         "session.commit() - is an after_flush() hook "
#    1291         "creating new objects?"
#    1292     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\session.py:4331, in Session.flush(self, objects)
#    4329 try:
#    4330     self._flushing = True
# -> 4331     self._flush(objects)
#    4332 finally:
#    4333     self._flushing = False
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\session.py:4466, in Session._flush(self, objects)
#    4463     transaction.commit()
#    4465 except:
# -> 4466     with util.safe_reraise():
#    4467         transaction.rollback(_capture_exception=True)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\session.py:4427, in Session._flush(self, objects)
#    4425 self._warn_on_events = True
#    4426 try:
# -> 4427     flush_context.execute()
#    4428 finally:
#    4429     self._warn_on_events = False
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\unitofwork.py:466, in UOWTransaction.execute(self)
#     464 else:
#     465     for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466         rec.execute(self)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\persistence.py:93, in save_obj(base_mapper, states, uowtransaction, single)
#      81     update = _collect_update_commands(
#      82         uowtransaction, table, states_to_update
#      83     )
#      85     _emit_update_statements(
#      86         base_mapper,
#      87         uowtransaction,
#    (...)
#      90         update,
#      91     )
# ---> 93     _emit_insert_statements(
#      94         base_mapper,
#      95         uowtransaction,
#      96         mapper,
#      97         table,
#      98         insert,
#      99     )
#     101 _finalize_insert_update_commands(
#     102     base_mapper,
#     103     uowtransaction,
#    (...)
#     119     ),
#     120 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\persistence.py:1048, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1045 records = list(records)
#    1046 multiparams = [rec[2] for rec in records]
# -> 1048 result = connection.execute(
#    1049     statement, multiparams, execution_options=execution_options
#    1050 )
#    1051 if bookkeeping:
#    1052     for (
#    1053         (
#    1054             state,
#    (...)
#    1063         last_inserted_params,
#    1064     ) in zip(records, result.context.compiled_parameters):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\sql\elements.py:527, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     525     if TYPE_CHECKING:
#     526         assert isinstance(self, Executable)
# --> 527     return connection._execute_clauseelement(
#     528         self, distilled_params, execution_options
#     529     )
#     530 else:
#     531     raise exc.ObjectNotExecutableError(self)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1629 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1630     "compiled_cache", self.engine._compiled_cache
#    1631 )
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)
#    1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#    1654     self.dispatch.after_execute(
#    1655         self,
#    1656         elem,
#    (...)
#    1660         ret,
#    1661     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:1844, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841 context.pre_exec()
#    1843 if context.execute_style is ExecuteStyle.INSERTMANYVALUES:
# -> 1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
#    1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:2133, in Connection._exec_insertmany_context(self, dialect, context)
#    2125         dialect.do_execute(
#    2126             cursor,
#    2127             sub_stmt,
#    2128             sub_params,
#    2129             context,
#    2130         )
#    2132 except BaseException as e:
# -> 2133     self._handle_dbapi_exception(
#    2134         e,
#    2135         sql_util._long_statement(sub_stmt),
#    2136         sub_params,
#    2137         cursor,
#    2138         context,
#    2139         is_sub_exec=True,
#    2140     )
#    2142 if engine_events:
#    2143     self.dispatch.after_cursor_execute(
#    2144         self,
#    2145         cursor,
#    (...)
#    2150         context.executemany,
#    2151     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:2363, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2361 elif should_wrap:
#    2362     assert sqlalchemy_exception is not None
# -> 2363     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2364 else:
#    2365     assert exc_info[1] is not None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:2125, in Connection._exec_insertmany_context(self, dialect, context)
#    2123             break
#    2124     else:
# -> 2125         dialect.do_execute(
#    2126             cursor,
#    2127             sub_stmt,
#    2128             sub_params,
#    2129             context,
#    2130         )
#    2132 except BaseException as e:
#    2133     self._handle_dbapi_exception(
#    2134         e,
#    2135         sql_util._long_statement(sub_stmt),
#    (...)
#    2139         is_sub_exec=True,
#    2140     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# IntegrityError: (pyodbc.IntegrityError) ('23000', '[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Конфликт инструкции INSERT с ограничением FOREIGN KEY "FK__PLANN__GROUP_ID__71D1E811". Конфликт произошел в базе данных "hico69_laba_sql", таблица "dbo.GROUPS", column \'GROUP_ID\'. (547) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Выполнение данной инструкции было прервано. (3621)')
# [SQL: INSERT INTO [PLANN] ([SUBJECT_ID], [GROUP_ID]) VALUES (?, ?), (?, ?), (?, ?), (?, ?), (?, ?), (?, ?)]
# [parameters: (1, 4, 2, 4, 3, 5, 4, 5, 5, 6, 6, 6)]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %% [markdown]
# ЗАДАНИЕ 4

# %%
new_g = GROUPS(NAME_GROUP="ПО134", COURSE=1)
session.add(new_g)
session.commit()

session.query(PLANN).filter(PLANN.GROUP_ID == 1).update({PLANN.GROUP_ID: new_g.GROUP_ID})
session.query(STUDENTS).filter(STUDENTS.GROUP_ID == 1).update({STUDENTS.GROUP_ID: new_g.GROUP_ID})
session.commit()

# %% [markdown]
# ЗАДАНИЕ 5

# %%
session.query(GROUPS).filter(GROUPS.NAME_GROUP == "ПО135").delete()
session.commit()

# %% [markdown]
# ЗАДАНИЕ 6

# %%
session.query(SUBJECTS).filter(SUBJECTS.SUBJECT_NAME == "Средства визуального программирования").update({SUBJECTS.SUBJECT_HOURS: 120})
session.query(SUBJECTS).filter(SUBJECTS.SUBJECT_NAME == "Объектно-ориентированное программирование").update({SUBJECTS.SUBJECT_HOURS: 100})
session.commit()
# Out:
# 2026-04-10 13:19:17,796 INFO sqlalchemy.engine.Engine UPDATE [SUBJECTS] SET [SUBJECT_HOURS]=? WHERE [SUBJECTS].[SUBJECT_NAME] = ?
# 2026-04-10 13:19:17,797 INFO sqlalchemy.engine.Engine [generated in 0.00124s] (120, 'Средства визуального программирования')
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# Error: ('40001', '[40001] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Транзакция (идентификатор процесса 98) вызвала взаимоблокировку ресурсов блокировка с другим процессом и стала жертвой взаимоблокировки. Запустите транзакцию повторно. (1205) (SQLExecDirectW)')
#
# The above exception was the direct cause of the following exception:
#
# DBAPIError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 session.query(SUBJECTS).filter(SUBJECTS.SUBJECT_NAME == "Средства визуального программирования").update({SUBJECTS.SUBJECT_HOURS: 120})
#       2 session.query(SUBJECTS).filter(SUBJECTS.SUBJECT_NAME == "Объектно-ориентированное программирование").update({SUBJECTS.SUBJECT_HOURS: 100})
#       3 session.commit()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\query.py:3304, in Query.update(self, values, synchronize_session, update_args)
#    3299     upd = upd.with_dialect_options(**update_args)
#    3301 upd._where_criteria = self._where_criteria
#    3302 result = cast(
#    3303     "CursorResult[Any]",
# -> 3304     self.session.execute(
#    3305         upd,
#    3306         self._params,
#    3307         execution_options=self._execution_options.union(
#    3308             {"synchronize_session": synchronize_session}
#    3309         ),
#    3310     ),
#    3311 )
#    3312 bulk_ud.result = result  # type: ignore
#    3313 self.session.dispatch.after_bulk_update(bulk_ud)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\session.py:2351, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2291 def execute(
#    2292     self,
#    2293     statement: Executable,
#    (...)
#    2299     _add_event: Optional[Any] = None,
#    2300 ) -> Result[Any]:
#    2301     r"""Execute a SQL expression construct.
#    2302
#    2303     Returns a :class:`_engine.Result` object representing
#    (...)
#    2349
#    2350     """
# -> 2351     return self._execute_internal(
#    2352         statement,
#    2353         params,
#    2354         execution_options=execution_options,
#    2355         bind_arguments=bind_arguments,
#    2356         _parent_execute_state=_parent_execute_state,
#    2357         _add_event=_add_event,
#    2358     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\session.py:2249, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2244     return conn.scalar(
#    2245         statement, params or {}, execution_options=execution_options
#    2246     )
#    2248 if compile_state_cls:
# -> 2249     result: Result[Any] = compile_state_cls.orm_execute_statement(
#    2250         self,
#    2251         statement,
#    2252         params or {},
#    2253         execution_options,
#    2254         bind_arguments,
#    2255         conn,
#    2256     )
#    2257 else:
#    2258     result = conn.execute(
#    2259         statement, params or {}, execution_options=execution_options
#    2260     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\bulk_persistence.py:1660, in BulkORMUpdate.orm_execute_statement(cls, session, statement, params, execution_options, bind_arguments, conn)
#    1651     return cls.orm_setup_cursor_result(
#    1652         session,
#    1653         statement,
#    (...)
#    1657         result,
#    1658     )
#    1659 else:
# -> 1660     return super().orm_execute_statement(
#    1661         session,
#    1662         statement,
#    1663         params,
#    1664         execution_options,
#    1665         bind_arguments,
#    1666         conn,
#    1667     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\orm\context.py:306, in AbstractORMCompileState.orm_execute_statement(cls, session, statement, params, execution_options, bind_arguments, conn)
#     296 @classmethod
#     297 def orm_execute_statement(
#     298     cls,
#    (...)
#     304     conn,
#     305 ) -> Result:
# --> 306     result = conn.execute(
#     307         statement, params or {}, execution_options=execution_options
#     308     )
#     309     return cls.orm_setup_cursor_result(
#     310         session,
#     311         statement,
#    (...)
#     315         result,
#     316     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\sql\elements.py:527, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     525     if TYPE_CHECKING:
#     526         assert isinstance(self, Executable)
# --> 527     return connection._execute_clauseelement(
#     528         self, distilled_params, execution_options
#     529     )
#     530 else:
#     531     raise exc.ObjectNotExecutableError(self)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1629 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1630     "compiled_cache", self.engine._compiled_cache
#    1631 )
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)
#    1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#    1654     self.dispatch.after_execute(
#    1655         self,
#    1656         elem,
#    (...)
#    1660         ret,
#    1661     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:2363, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2361 elif should_wrap:
#    2362     assert sqlalchemy_exception is not None
# -> 2363     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2364 else:
#    2365     assert exc_info[1] is not None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)
#    1978         context.executemany,
#    1979     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# DBAPIError: (pyodbc.Error) ('40001', '[40001] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Транзакция (идентификатор процесса 98) вызвала взаимоблокировку ресурсов блокировка с другим процессом и стала жертвой взаимоблокировки. Запустите транзакцию повторно. (1205) (SQLExecDirectW)')
# [SQL: UPDATE [SUBJECTS] SET [SUBJECT_HOURS]=? WHERE [SUBJECTS].[SUBJECT_NAME] = ?]
# [parameters: (120, 'Средства визуального программирования')]
# (Background on this error at: https://sqlalche.me/e/20/dbapi)

# %% [markdown]
# ЗАДАНИЕ 7

# %%
session.execute(text("ALTER TABLE SUBJECTS ADD EXAM_TYPE NVARCHAR(10)"))
session.commit()
session.execute(text("UPDATE SUBJECTS SET EXAM_TYPE = 'Экзамен'"))
session.execute(text("UPDATE SUBJECTS SET EXAM_TYPE = 'Зачёт' WHERE name_subject = 'Основы алгоритмизации'"))
session.commit()

# %% [markdown]
# ЗАДАНИЕ 8

# %%
session.execute(text("ALTER TABLE STUDENTS DROP COLUMN second_name"))
session.commit()

# %%
session.close()
